# %%
# !pip install numpy pandas matplotlib seaborn scikit-learn
# Out:
# Requirement already satisfied: numpy in c:\users\jayalakshmi\desktop\infosys\.venv\lib\site-packages (2.2.6)
# Requirement already satisfied: pandas in c:\users\jayalakshmi\desktop\infosys\.venv\lib\site-packages (2.3.3)
# Collecting matplotlib
#   Using cached matplotlib-3.10.8-cp310-cp310-win_amd64.whl (8.1 MB)
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Requirement already satisfied: scikit-learn in c:\users\jayalakshmi\desktop\infosys\.venv\lib\site-packages (1.7.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jayalakshmi\desktop\infosys\.venv\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jayalakshmi\desktop\infosys\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jayalakshmi\desktop\infosys\.venv\lib\site-packages (from pandas) (2025.2)
# Collecting pillow>=8
#   Using cached pillow-12.0.0-cp310-cp310-win_amd64.whl (7.0 MB)
# Collecting kiwisolver>=1.3.1
#   Using cached kiwisolver-1.4.9-cp310-cp310-win_amd64.whl (73 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\jayalakshmi\desktop\infosys\.venv\lib\site-packages (from matplotlib) (25.0)
# Collecting cycler>=0.10
#   Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Requirement already satisfied: pyparsing>=3 in c:\users\jayalakshmi\desktop\infosys\.venv\lib\site-packages (from matplotlib) (3.2.5)
# Collecting contourpy>=1.0.1
#   Using cached contourpy-1.3.2-cp310-cp310-win_amd64.whl (221 kB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.61.1-cp310-cp310-win_amd64.whl (1.6 MB)
#      ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#      --- ------------------------------------ 0.2/1.6 MB 9.0 MB/s eta 0:00:01
#      --------- ------------------------------ 0.4/1.6 MB 3.7 MB/s eta 0:00:01
#      ---------------- ----------------------- 0.6/1.6 MB 5.0 MB/s eta 0:00:01
#      --------------------- ------------------ 0.8/1.6 MB 4.9 MB/s eta 0:00:01
#      -------------------------- ------------- 1.0/1.6 MB 4.4 MB/s eta 0:00:01
#      ----------------------------- ---------- 1.1/1.6 MB 4.2 MB/s eta 0:00:01
#      ------------------------------- -------- 1.2/1.6 MB 3.9 MB/s eta 0:00:01
#      --------------------------------- ------ 1.3/1.6 MB 3.6 MB/s eta 0:00:01
#      -------------------------------------- - 1.5/1.6 MB 3.7 MB/s eta 0:00:01
#      ---------------------------------------- 1.6/1.6 MB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.8.0 in c:\users\jayalakshmi\desktop\infosys\.venv\lib\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\jayalakshmi\desktop\infosys\.venv\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\jayalakshmi\desktop\infosys\.venv\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: six>=1.5 in c:\users\jayalakshmi\desktop\infosys\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Installing collected packages: pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib, seaborn
# Successfully installed contourpy-1.3.2 cycler-0.12.1 fonttools-4.61.1 kiwisolver-1.4.9 matplotlib-3.10.8 pillow-12.0.0 seaborn-0.13.2
# [notice] A new release of pip is available: 23.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# ----------------------------
# 1. LOAD DATASET
# ----------------------------
FILE_PATH = "fundamental.csv"   # change if filename differs

df = pd.read_csv(FILE_PATH)

print("\n========== BASIC INFO ==========")
print(df.info())

print("\n========== SHAPE ==========")
print(df.shape)

print("\n========== FIRST 5 ROWS ==========")
print(df.head())
# Out:
#           symbol  revenuePerShare  trailingPE  earningsQuarterlyGrowth  \
# 0    RELIANCE.BO         1296.823   28.012129                    0.093
# 1    RELIANCE.NS         1296.823   28.010878                    0.093
# 2    HDFCBANK.BO          293.740   16.260424                    0.359
# 3  HINDUNILVR.NS          263.412   51.285230                    0.014
# 4   ICICIBANK.NS          197.399   18.315136                    0.257
#
#    previousClose     open   dayLow  dayHigh      volume  trailingEps  \
# 0        2901.30  2897.05  2895.35   2920.0    562484.0       103.88
# 1        2901.95  2899.95  2894.70   2920.0   9763420.0       103.89
# 2        1445.10  1437.30  1437.30   1450.7    783356.0        88.74
# 3        2242.35  2239.05  2232.05   2266.0   3507581.0        44.00
# 4        1081.80  1081.15  1078.70   1093.7  17212189.0        59.53
#
#    pegRatio        ebitda     totalDebt  totalRevenue  debtToEquity  \
# 0       NaN  1.503867e+12  3.166970e+12  8.773650e+12        36.100
# 1       NaN  1.503867e+12  3.166970e+12  8.773650e+12        36.100
# 2       NaN           NaN  7.996598e+12  1.933224e+12           NaN
# 3       NaN  1.421525e+11  1.272000e+10  6.190100e+11         2.515
# 4      1.03           NaN  2.009669e+12  1.380849e+12           NaN
#
#    revenuePerShare.1  earningsGrowth  revenueGrowth
# 0           1296.823           0.093          0.036
# 1           1296.823           0.093          0.036
# 2            293.740          -0.001          1.211
# 3            263.412           0.014         -0.002
# 4            197.399           0.253          0.204

# %%
# ----------------------------
# 2. COLUMN NAMES CLEANING
# ----------------------------
df.columns = (
    df.columns
    .str.strip()
    .str.replace(" ", "_")
    .str.replace("%", "Percent")
)

print("\n========== CLEANED COLUMN NAMES ==========")
print(df.columns.tolist())
# Out:
# ========== CLEANED COLUMN NAMES ==========
# ['symbol', 'revenuePerShare', 'trailingPE', 'earningsQuarterlyGrowth', 'previousClose', 'open', 'dayLow', 'dayHigh', 'volume', 'trailingEps', 'pegRatio', 'ebitda', 'totalDebt', 'totalRevenue', 'debtToEquity', 'revenuePerShare.1', 'earningsGrowth', 'revenueGrowth']

# %%
# ----------------------------
# 3. CHECK MISSING VALUES
# ----------------------------
print("\n========== MISSING VALUES ==========")
missing = df.isnull().sum()
print(missing[missing > 0])
# Out:
# ========== MISSING VALUES ==========
# revenuePerShare            2675
# trailingPE                 2528
# earningsQuarterlyGrowth    3584
# previousClose               580
# open                        578
# dayLow                      578
# dayHigh                     578
# volume                      578
# trailingEps                2668
# pegRatio                   5557
# ebitda                     2898
# totalDebt                  2839
# totalRevenue               2676
# debtToEquity               3170
# revenuePerShare.1          2675
# earningsGrowth             3622
# revenueGrowth              2739
# dtype: int64

# %%
# ----------------------------
# 4. SEPARATE NUMERIC & CATEGORICAL
# ----------------------------
numeric_cols = df.select_dtypes(include=[np.number]).columns
categorical_cols = df.select_dtypes(exclude=[np.number]).columns

print("\nNumeric columns:")
print(list(numeric_cols))

print("\nCategorical columns:")
print(list(categorical_cols))
# Out:
# Numeric columns:
# ['revenuePerShare', 'trailingPE', 'earningsQuarterlyGrowth', 'previousClose', 'open', 'dayLow', 'dayHigh', 'volume', 'trailingEps', 'pegRatio', 'ebitda', 'totalDebt', 'totalRevenue', 'debtToEquity', 'revenuePerShare.1', 'earningsGrowth', 'revenueGrowth']
#
# Categorical columns:
# ['symbol']

# %%
# ----------------------------
# 5. HANDLE MISSING VALUES
# ----------------------------

# Numeric → median (robust)
for col in numeric_cols:
    if df[col].isnull().sum() > 0:
        median_value = df[col].median()
        df[col].fillna(median_value, inplace=True)

# Categorical → mode
for col in categorical_cols:
    if df[col].isnull().sum() > 0:
        mode_value = df[col].mode()[0]
        df[col].fillna(mode_value, inplace=True)

print("\n========== MISSING VALUES AFTER CLEANING ==========")
print(df.isnull().sum().sum(), "total null values")
# Out:
# ========== MISSING VALUES AFTER CLEANING ==========
# 0 total null values
# C:\Users\Jayalakshmi\AppData\Local\Temp\ipykernel_10116\648638251.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(median_value, inplace=True)
# C:\Users\Jayalakshmi\AppData\Local\Temp\ipykernel_10116\648638251.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(median_value, inplace=True)
# C:\Users\Jayalakshmi\AppData\Local\Temp\ipykernel_10116\648638251.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(median_value, inplace=True)
# C:\Users\Jayalakshmi\AppData\Local\Temp\ipykernel_10116\648638251.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(median_value, inplace=True)
# C:\Users\Jayalakshmi\AppData\Local\Temp\ipykernel_10116\648638251.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(median_value, inplace=True)
# C:\Users\Jayalakshmi\AppData\Local\Temp\ipykernel_10116\648638251.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(median_value, inplace=True)
# C:\Users\Jayalakshmi\AppData\Local\Temp\ipykernel_10116\648638251.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(median_value, inplace=True)
# C:\Users\Jayalakshmi\AppData\Local\Temp\ipykernel_10116\648638251.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(median_value, inplace=True)
# C:\Users\Jayalakshmi\AppData\Local\Temp\ipykernel_10116\648638251.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(median_value, inplace=True)
# C:\Users\Jayalakshmi\AppData\Local\Temp\ipykernel_10116\648638251.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(median_value, inplace=True)
# C:\Users\Jayalakshmi\AppData\Local\Temp\ipykernel_10116\648638251.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(median_value, inplace=True)
# C:\Users\Jayalakshmi\AppData\Local\Temp\ipykernel_10116\648638251.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(median_value, inplace=True)
# C:\Users\Jayalakshmi\AppData\Local\Temp\ipykernel_10116\648638251.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(median_value, inplace=True)
# C:\Users\Jayalakshmi\AppData\Local\Temp\ipykernel_10116\648638251.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(median_value, inplace=True)
# C:\Users\Jayalakshmi\AppData\Local\Temp\ipykernel_10116\648638251.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(median_value, inplace=True)
# C:\Users\Jayalakshmi\AppData\Local\Temp\ipykernel_10116\648638251.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(median_value, inplace=True)
# C:\Users\Jayalakshmi\AppData\Local\Temp\ipykernel_10116\648638251.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(median_value, inplace=True)

# %%
# ----------------------------
# 6. SYMBOL COLUMN CHECK (VERY IMPORTANT)
# ----------------------------
if "symbol" in df.columns:
    df["symbol"] = df["symbol"].str.strip().str.upper()
else:
    raise Exception("❌ SYMBOL column missing. This dataset is not suitable for watchlist.")

print("\nUnique companies count:", df["symbol"].nunique())
# Out:
# Unique companies count: 5829

# %%
# ----------------------------
# 7. REMOVE DUPLICATES (IF ANY)
# ----------------------------
before = df.shape[0]
df.drop_duplicates(inplace=True)
after = df.shape[0]

print(f"\nDuplicates removed: {before - after}")
# Out:
# Duplicates removed: 81

# %%
# ----------------------------
# 8. DESCRIPTIVE STATISTICS (EDA CORE)
# ----------------------------
print("\n========== DESCRIPTIVE STATS ==========")
print(df.describe())
# Out:
# ========== DESCRIPTIVE STATS ==========
#        revenuePerShare   trailingPE  earningsQuarterlyGrowth  previousClose  \
# count      5829.000000  5829.000000              5829.000000    5829.000000
# mean        264.382839          inf                 0.620612     618.090009
# std        1181.765731          NaN                 7.249778    3064.934828
# min         -28.928000     0.025160                -0.998000       0.030000
# 25%         111.958000    26.179459                 0.187000      35.100000
# 50%         135.804000    29.994380                 0.187000     126.525000
# 75%         162.387000    34.973700                 0.187000     427.400000
# max       58164.040000          inf               311.196000  131639.050000
#
#                 open         dayLow        dayHigh        volume  trailingEps  \
# count    5829.000000    5829.000000    5829.000000  5.829000e+03  5829.000000
# mean      619.056457     611.511247     632.486455  7.092336e+05    14.007071
# std      3065.879609    3039.985604    3102.782818  7.966188e+06   183.656852
# min         0.030000       0.030000       0.030000  1.000000e+00 -7848.510000
# 25%        35.480000      34.150000      36.600000  3.875000e+03     7.010000
# 50%       126.225000     124.000000     130.250000  1.891150e+04     8.535000
# 75%       424.750000     421.250000     435.900000  9.960400e+04    10.680000
# max    131700.000000  130592.650000  132749.900000  4.684809e+08  4780.210000
#
#           pegRatio        ebitda     totalDebt  totalRevenue  debtToEquity  \
# count  5829.000000  5.829000e+03  5.829000e+03  5.829000e+03   5829.000000
# mean      1.653158  6.909760e+09  3.896918e+10  5.354662e+10     71.203215
# std      19.698228  4.969295e+10  3.204951e+11  3.342161e+11    718.327794
# min    -120.870000 -2.968675e+10  1.000000e+05 -7.920600e+09      0.002000
# 25%       1.260000  1.030624e+09  1.863200e+09  8.543179e+09     29.920000
# 50%       1.260000  1.118691e+09  2.152000e+09  1.121537e+10     29.920000
# 75%       1.260000  1.178008e+09  2.481869e+09  1.368210e+10     29.920000
# max    1059.900000  1.503867e+12  8.455658e+12  8.773650e+12  37076.363000
#
#        revenuePerShare.1  earningsGrowth  revenueGrowth
# count        5829.000000     5829.000000    5829.000000
# mean          264.382839        0.523395       0.298441
# std          1181.765731        5.192396       5.305371
# min           -28.928000       -0.998000      -0.999000
# 25%           111.958000        0.168000       0.053000
# 50%           135.804000        0.168000       0.069000
# 75%           162.387000        0.168000       0.086000
# max         58164.040000      233.500000     191.250000
# c:\Users\Jayalakshmi\Desktop\infosys\.venv\lib\site-packages\pandas\core\nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)

# %%
# ----------------------------
# 9. SAVE CLEANED DATASET
# ----------------------------
OUTPUT_FILE = "fundamental_cleaned.csv"
df.to_csv(OUTPUT_FILE, index=False)

print(f"\nCLEANED DATASET SAVED AS: {OUTPUT_FILE}")
# Out:
# CLEANED DATASET SAVED AS: fundamental_cleaned.csv
